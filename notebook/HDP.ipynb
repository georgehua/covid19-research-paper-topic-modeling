# %%
try:
    # %load_ext autotime
except:
    # !pip install ipython-autotime
    # %load_ext autotime
    
import numpy as np 
import pandas as pd
from tqdm import tqdm
# Out:
# time: 906 ms

# %% [markdown]
# # Load and Prepare Data

# %%
# load preprocessed full info df
df = pd.read_csv('../data/df_cleaned.csv')
print(df.shape)
# Out:
# (309120, 5)
# time: 6.48 s

# %%
df.isna().sum()
# Out:
# title               16
# abstract             0
# publish_time       175
# authors           2279
# url             101337
# dtype: int64
# time: 125 ms

# %%
df.head()
# Out:
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
#
#                                             abstract publish_time  \
# 0  objective retrospective chart describes epidem...   2001-07-04
# 1  inflammatory diseases respiratory tract common...   2000-08-15
# 2  surfactant protein-d sp-d participates innate ...   2000-08-25
# 3  endothelin-1 et-1 amino acid peptide diverse b...   2001-02-22
# 4  respiratory syncytial virus rsv pneumonia viru...   2001-05-11
#
#                                              authors  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                    Crouch, Erika C
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...
#
#                                                  url
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# time: 15 ms

# %% [markdown]
# We consider the text body, but the approach could also be applied to the abstracts only.

# %%
# load preprocessed and tokenized vector for building model directly
docs = np.load("../data/docs.npy", allow_pickle=True)
# Out:
# time: 23.9 s

# %% [markdown]
# ## HDP

# %%
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
# Out:
# time: 3.69 s
# C:\Users\George\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.5)
# Out:
# time: 59.2 s

# %%
# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]
# Out:
# time: 32.8 s

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 58177
# Number of documents: 309120
# time: 0 ns

# %%
from gensim.models import HdpModel
model = HdpModel(corpus = corpus, id2word = dictionary)
# Out:
# time: 34min 40s

# %%
hdp_topics = model.print_topics()
for topic in hdp_topics: 
    print(topic)
# Out:
# (0, '0.015*covid + 0.009*health + 0.008*pandemic + 0.004*care + 0.004*data + 0.004*patients + 0.004*social + 0.003*disease + 0.003*risk + 0.003*public')
# (1, '0.024*patients + 0.011*covid + 0.005*clinical + 0.004*risk + 0.004*treatment + 0.004*disease + 0.004*methods + 0.004*mortality + 0.004*associated + 0.003*hospital')
# (2, '0.014*cov + 0.013*sars + 0.012*sars_cov + 0.008*covid + 0.007*virus + 0.006*viral + 0.005*coronavirus + 0.005*protein + 0.005*disease + 0.005*infection')
# (3, '0.011*cells + 0.007*cell + 0.007*infection + 0.006*covid + 0.005*virus + 0.005*patients + 0.005*expression + 0.004*immune + 0.004*disease + 0.004*viral')
# (4, '0.008*sars + 0.008*cov + 0.007*sars_cov + 0.007*virus + 0.006*samples + 0.006*patients + 0.006*respiratory + 0.005*pcr + 0.005*covid + 0.005*infection')
# (5, '0.027*covid + 0.023*patients + 0.010*disease + 0.010*sars + 0.010*cov + 0.009*sars_cov + 0.007*infection + 0.007*coronavirus + 0.007*severe + 0.006*respiratory')
# (6, '0.006*model + 0.005*covid + 0.005*data + 0.003*time + 0.003*different + 0.003*models + 0.003*analysis + 0.003*method + 0.002*high + 0.002*new')
# (7, '0.003*covid + 0.002*pandemic + 0.001*health + 0.001*influenza + 0.001*coronavirus + 0.001*disease + 0.001*cells + 0.001*virus + 0.001*cell + 0.001*patients')
# (8, '0.003*covid + 0.002*influenza + 0.002*pandemic + 0.002*health + 0.002*disease + 0.001*coronavirus + 0.001*viruses + 0.001*patients + 0.001*data + 0.001*background')
# (9, '0.003*covid + 0.002*patients + 0.002*disease + 0.001*pandemic + 0.001*health + 0.001*coronavirus + 0.001*virus + 0.001*care + 0.001*respiratory + 0.001*infection')
# (10, '0.003*covid + 0.002*pandemic + 0.001*disease + 0.001*health + 0.001*coronavirus + 0.001*influenza + 0.001*background + 0.001*virus + 0.001*patients + 0.001*infection')
# (11, '0.003*covid + 0.002*pandemic + 0.001*influenza + 0.001*health + 0.001*disease + 0.001*coronavirus + 0.001*background + 0.001*data + 0.001*infection + 0.001*new')
# (12, '0.002*covid + 0.002*disease + 0.001*pandemic + 0.001*patients + 0.001*health + 0.001*coronavirus + 0.001*influenza + 0.001*population + 0.001*infection + 0.001*spread')
# (13, '0.001*covid + 0.001*health + 0.001*protein + 0.001*viral + 0.001*disease + 0.001*virus + 0.001*pandemic + 0.001*cells + 0.001*influenza + 0.001*public')
# (14, '0.002*covid + 0.001*viral + 0.001*virus + 0.001*pandemic + 0.001*disease + 0.001*cd + 0.001*human + 0.001*viruses + 0.001*health + 0.000*cells')
# (15, '0.001*covid + 0.001*pandemic + 0.001*virus + 0.001*influenza + 0.001*health + 0.001*disease + 0.000*coronavirus + 0.000*viruses + 0.000*background + 0.000*human')
# (16, '0.001*covid + 0.001*disease + 0.001*ifn + 0.001*pandemic + 0.001*patients + 0.001*production + 0.001*lung + 0.001*virus + 0.000*complement + 0.000*infection')
# (17, '0.002*patients + 0.001*covid + 0.001*pandemic + 0.001*pneumonia + 0.001*influenza + 0.001*disease + 0.001*years + 0.001*infection + 0.001*respiratory + 0.001*coronavirus')
# (18, '0.001*covid + 0.001*infection + 0.001*health + 0.001*disease + 0.001*patients + 0.001*hiv + 0.000*upr + 0.000*malaria + 0.000*pandemic + 0.000*cells')
# (19, '0.001*microarray + 0.001*ssh + 0.001*expression + 0.001*genes + 0.001*assays + 0.001*covid + 0.001*cell + 0.001*cells + 0.001*high + 0.001*tls')
# time: 1.16 s

# %%
for idx, topic in model.show_topics(formatted=False, num_words= 10):
    print('Topic: {} \nWords: {}'.format(idx, [w[0] for w in topic]))
# Out:
# Topic: 0
# Words: ['covid', 'health', 'pandemic', 'care', 'data', 'patients', 'social', 'disease', 'risk', 'public']
# Topic: 1
# Words: ['patients', 'covid', 'clinical', 'risk', 'treatment', 'disease', 'methods', 'mortality', 'associated', 'hospital']
# Topic: 2
# Words: ['cov', 'sars', 'sars_cov', 'covid', 'virus', 'viral', 'coronavirus', 'protein', 'disease', 'infection']
# Topic: 3
# Words: ['cells', 'cell', 'infection', 'covid', 'virus', 'patients', 'expression', 'immune', 'disease', 'viral']
# Topic: 4
# Words: ['sars', 'cov', 'sars_cov', 'virus', 'samples', 'patients', 'respiratory', 'pcr', 'covid', 'infection']
# Topic: 5
# Words: ['covid', 'patients', 'disease', 'sars', 'cov', 'sars_cov', 'infection', 'coronavirus', 'severe', 'respiratory']
# Topic: 6
# Words: ['model', 'covid', 'data', 'time', 'different', 'models', 'analysis', 'method', 'high', 'new']
# Topic: 7
# Words: ['covid', 'pandemic', 'health', 'influenza', 'coronavirus', 'disease', 'cells', 'virus', 'cell', 'patients']
# Topic: 8
# Words: ['covid', 'influenza', 'pandemic', 'health', 'disease', 'coronavirus', 'viruses', 'patients', 'data', 'background']
# Topic: 9
# Words: ['covid', 'patients', 'disease', 'pandemic', 'health', 'coronavirus', 'virus', 'care', 'respiratory', 'infection']
# Topic: 10
# Words: ['covid', 'pandemic', 'disease', 'health', 'coronavirus', 'influenza', 'background', 'virus', 'patients', 'infection']
# Topic: 11
# Words: ['covid', 'pandemic', 'influenza', 'health', 'disease', 'coronavirus', 'background', 'data', 'infection', 'new']
# Topic: 12
# Words: ['covid', 'disease', 'pandemic', 'patients', 'health', 'coronavirus', 'influenza', 'population', 'infection', 'spread']
# Topic: 13
# Words: ['covid', 'health', 'protein', 'viral', 'disease', 'virus', 'pandemic', 'cells', 'influenza', 'public']
# Topic: 14
# Words: ['covid', 'viral', 'virus', 'pandemic', 'disease', 'cd', 'human', 'viruses', 'health', 'cells']
# Topic: 15
# Words: ['covid', 'pandemic', 'virus', 'influenza', 'health', 'disease', 'coronavirus', 'viruses', 'background', 'human']
# Topic: 16
# Words: ['covid', 'disease', 'ifn', 'pandemic', 'patients', 'production', 'lung', 'virus', 'complement', 'infection']
# Topic: 17
# Words: ['patients', 'covid', 'pandemic', 'pneumonia', 'influenza', 'disease', 'years', 'infection', 'respiratory', 'coronavirus']
# Topic: 18
# Words: ['covid', 'infection', 'health', 'disease', 'patients', 'hiv', 'upr', 'malaria', 'pandemic', 'cells']
# Topic: 19
# Words: ['microarray', 'ssh', 'expression', 'genes', 'assays', 'covid', 'cell', 'cells', 'high', 'tls']
# time: 1.28 s

# %%
# Compute Coherence Score
coherence_model = CoherenceModel(model=model, texts=docs, dictionary=dictionary, coherence='c_v')
coherence = coherence_model.get_coherence()
print('\nCoherence Score: ', coherence)
# Out:
# Coherence Score:  0.39324078620342945
# time: 11min 26s
